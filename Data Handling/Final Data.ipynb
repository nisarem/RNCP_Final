# %%
import gzip
import pandas as pd
import numpy as np
import pickle
import requests
import logging
import time
import random
import re
import json

f = open("token_TMDB.txt","r")
token = f.read()
headers = {"accept": "application/json", "Authorization": f"Bearer {token}"}

# %%
movies = pickle.load(open('movies2.pkl', 'rb'))

# %%
movies
# Out:
#              tconst              primaryTitle                   originalTitle  \
# 28768     tt0029284          My Favorite Wife                My Favorite Wife
# 30799     tt0031359                  Gaslight                        Gaslight
# 31405     tt0031976       The Stars Look Down             The Stars Look Down
# 31600     tt0032179          21 Days Together                         21 Days
# 31602     tt0032181   Abe Lincoln in Illinois         Abe Lincoln in Illinois
# ...             ...                       ...                             ...
# 10698589  tt9907782                The Cursed                Eight for Silver
# 10698877  tt9908390                   Le lion                         Le lion
# 10700132  tt9911196       The Marriage Escape  De beentjes van Sint-Hildegard
# 10702488  tt9916270  Il talento del calabrone        Il talento del calabrone
# 10702533  tt9916362                     Coven                        Akelarre
#
#           startYear  runtimeMinutes                   genres  \
# 28768          1940              88           Comedy,Romance
# 30799          1940              84         Mystery,Thriller
# 31405          1940             110                    Drama
# 31600          1940              72      Crime,Drama,Romance
# 31602          1940             110  Biography,Drama,History
# ...             ...             ...                      ...
# 10698589       2021             111   Fantasy,Horror,Mystery
# 10698877       2020              95                   Comedy
# 10700132       2020             103             Comedy,Drama
# 10702488       2020              84                 Thriller
# 10702533       2020              92            Drama,History
#
#                                                    keywords  \
# 28768     {'keywords': [{'id': 931, 'name': 'jealousy'},...
# 30799     {'keywords': [{'id': 6038, 'name': 'marriage'}...
# 31405     {'keywords': [{'id': 6346, 'name': 'trade unio...
# 31600     {'keywords': [{'id': 171989, 'name': 'wrongful...
# 31602     {'keywords': [{'id': 5565, 'name': 'biography'...
# ...                                                     ...
# 10698589  {'keywords': [{'id': 394, 'name': 'gypsy'}, {'...
# 10698877  {'keywords': [{'id': 5265, 'name': 'espionage'}]}
# 10700132                                   {'keywords': []}
# 10702488                                   {'keywords': []}
# 10702533  {'keywords': [{'id': 344, 'name': 'inquisition...
#
#                                                    overview  \
# 28768     Years after she was presumed dead in a shipwre...
# 30799     Twenty years removed from Alice Barlow's murde...
# 31405     Davey Fenwick leaves his mining village on a u...
# 31600     After Larry Darrent accidentally kills his lov...
# 31602     Abe Lincoln in Illinois is a 1940 biographical...
# ...                                                     ...
# 10698589  In the late 19th century, a brutal land baron ...
# 10698877  A psychiatric hospital patient pretends to be ...
# 10700132  Jan has been married to Gedda for 35 years. Ge...
# 10702488  Dj Steph is a young radio deejay on the rise, ...
# 10702533  French Basque Country, year 1609. The men of a...
#
#                                        production_countries  \
# 28768     [{'iso_3166_1': 'US', 'name': 'United States o...
# 30799      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 31405      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 31600      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 31602     [{'iso_3166_1': 'US', 'name': 'United States o...
# ...                                                     ...
# 10698589  [{'iso_3166_1': 'US', 'name': 'United States o...
# 10698877           [{'iso_3166_1': 'FR', 'name': 'France'}]
# 10700132      [{'iso_3166_1': 'NL', 'name': 'Netherlands'}]
# 10702488            [{'iso_3166_1': 'IT', 'name': 'Italy'}]
# 10702533  [{'iso_3166_1': 'AR', 'name': 'Argentina'}, {'...
#
#                                        production_companies
# 28768     [{'id': 6, 'logo_path': '/n53F7K9scQWFXYbrCabl...
# 30799     [{'id': 14197, 'logo_path': None, 'name': 'Bri...
# 31405     [{'id': 18700, 'logo_path': None, 'name': 'Gra...
# 31600     [{'id': 659, 'logo_path': None, 'name': 'Londo...
# 31602     [{'id': 6, 'logo_path': '/n53F7K9scQWFXYbrCabl...
# ...                                                     ...
# 10698589  [{'id': 26065, 'logo_path': None, 'name': 'Pis...
# 10698877  [{'id': 90562, 'logo_path': '/qII3jJQ4S32FgJRl...
# 10700132  [{'id': 60652, 'logo_path': '/pNlPbnwBkKgZsc2y...
# 10702488  [{'id': 3110, 'logo_path': '/snpwZMXBOwbLSHqrn...
# 10702533  [{'id': 6458, 'logo_path': '/eT4oMUK7ODM0vvZue...
#
# [32180 rows x 10 columns]

# %%
ratings = pickle.load(open('ratings.pkl', 'rb'))

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 13431    tt0029284            7.3     11501
# 15082    tt0031359            7.3      5264
# 15601    tt0031976            7.0      1178
# 15772    tt0032179            6.1      1276
# 15773    tt0032181            7.3      2052
# ...            ...            ...       ...
# 1426695  tt9907782            6.2     16278
# 1426700  tt9908390            5.5      1407
# 1426818  tt9911196            7.4      3321
# 1427052  tt9916270            5.8      1480
# 1427056  tt9916362            6.4      5770
#
# [32180 rows x 3 columns]

# %%
movies = pd.merge(movies, ratings, on='tconst', how='inner')

# %%
movies
# Out:
#           tconst              primaryTitle                   originalTitle  \
# 0      tt0029284          My Favorite Wife                My Favorite Wife
# 1      tt0031359                  Gaslight                        Gaslight
# 2      tt0031976       The Stars Look Down             The Stars Look Down
# 3      tt0032179          21 Days Together                         21 Days
# 4      tt0032181   Abe Lincoln in Illinois         Abe Lincoln in Illinois
# ...          ...                       ...                             ...
# 32175  tt9907782                The Cursed                Eight for Silver
# 32176  tt9908390                   Le lion                         Le lion
# 32177  tt9911196       The Marriage Escape  De beentjes van Sint-Hildegard
# 32178  tt9916270  Il talento del calabrone        Il talento del calabrone
# 32179  tt9916362                     Coven                        Akelarre
#
#        startYear  runtimeMinutes                   genres  \
# 0           1940              88           Comedy,Romance
# 1           1940              84         Mystery,Thriller
# 2           1940             110                    Drama
# 3           1940              72      Crime,Drama,Romance
# 4           1940             110  Biography,Drama,History
# ...          ...             ...                      ...
# 32175       2021             111   Fantasy,Horror,Mystery
# 32176       2020              95                   Comedy
# 32177       2020             103             Comedy,Drama
# 32178       2020              84                 Thriller
# 32179       2020              92            Drama,History
#
#                                                 keywords  \
# 0      {'keywords': [{'id': 931, 'name': 'jealousy'},...
# 1      {'keywords': [{'id': 6038, 'name': 'marriage'}...
# 2      {'keywords': [{'id': 6346, 'name': 'trade unio...
# 3      {'keywords': [{'id': 171989, 'name': 'wrongful...
# 4      {'keywords': [{'id': 5565, 'name': 'biography'...
# ...                                                  ...
# 32175  {'keywords': [{'id': 394, 'name': 'gypsy'}, {'...
# 32176  {'keywords': [{'id': 5265, 'name': 'espionage'}]}
# 32177                                   {'keywords': []}
# 32178                                   {'keywords': []}
# 32179  {'keywords': [{'id': 344, 'name': 'inquisition...
#
#                                                 overview  \
# 0      Years after she was presumed dead in a shipwre...
# 1      Twenty years removed from Alice Barlow's murde...
# 2      Davey Fenwick leaves his mining village on a u...
# 3      After Larry Darrent accidentally kills his lov...
# 4      Abe Lincoln in Illinois is a 1940 biographical...
# ...                                                  ...
# 32175  In the late 19th century, a brutal land baron ...
# 32176  A psychiatric hospital patient pretends to be ...
# 32177  Jan has been married to Gedda for 35 years. Ge...
# 32178  Dj Steph is a young radio deejay on the rise, ...
# 32179  French Basque Country, year 1609. The men of a...
#
#                                     production_countries  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...
# 1       [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 2       [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 3       [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...
# ...                                                  ...
# 32175  [{'iso_3166_1': 'US', 'name': 'United States o...
# 32176           [{'iso_3166_1': 'FR', 'name': 'France'}]
# 32177      [{'iso_3166_1': 'NL', 'name': 'Netherlands'}]
# 32178            [{'iso_3166_1': 'IT', 'name': 'Italy'}]
# 32179  [{'iso_3166_1': 'AR', 'name': 'Argentina'}, {'...
#
#                                     production_companies  averageRating  \
# 0      [{'id': 6, 'logo_path': '/n53F7K9scQWFXYbrCabl...            7.3
# 1      [{'id': 14197, 'logo_path': None, 'name': 'Bri...            7.3
# 2      [{'id': 18700, 'logo_path': None, 'name': 'Gra...            7.0
# 3      [{'id': 659, 'logo_path': None, 'name': 'Londo...            6.1
# 4      [{'id': 6, 'logo_path': '/n53F7K9scQWFXYbrCabl...            7.3
# ...                                                  ...            ...
# 32175  [{'id': 26065, 'logo_path': None, 'name': 'Pis...            6.2
# 32176  [{'id': 90562, 'logo_path': '/qII3jJQ4S32FgJRl...            5.5
# 32177  [{'id': 60652, 'logo_path': '/pNlPbnwBkKgZsc2y...            7.4
# 32178  [{'id': 3110, 'logo_path': '/snpwZMXBOwbLSHqrn...            5.8
# 32179  [{'id': 6458, 'logo_path': '/eT4oMUK7ODM0vvZue...            6.4
#
#        numVotes
# 0         11501
# 1          5264
# 2          1178
# 3          1276
# 4          2052
# ...         ...
# 32175     16278
# 32176      1407
# 32177      3321
# 32178      1480
# 32179      5770
#
# [32180 rows x 12 columns]

# %%
relations = pickle.load(open('cast_crew.pkl', 'rb'))

# %%
relations
# Out:
#              tconst      nconst profession
# 325941    tt0029284   nm0002050    actress
# 325942    tt0029284   nm0000026      actor
# 325943    tt0029284   nm0000068      actor
# 325944    tt0029284   nm0665850    actress
# 325945    tt0029284   nm0794700    actress
# ...             ...         ...        ...
# 10061808  tt9911196   nm2063122    writers
# 10064086  tt9916270  nm10538402    writers
# 10064086  tt9916270   nm1480867    writers
# 10064131  tt9916362   nm1893148    writers
# 10064131  tt9916362   nm3471432    writers
#
# [415935 rows x 3 columns]

# %%
people = pickle.load(open('people.pkl', 'rb'))

# %%
people
# Out:
#              nconst      primaryName  birthYear  deathYear  \
# 0         nm0000001     Fred Astaire     1899.0     1987.0
# 1         nm0000002    Lauren Bacall     1924.0     2014.0
# 2         nm0000003  Brigitte Bardot     1934.0        NaN
# 3         nm0000004     John Belushi     1949.0     1982.0
# 4         nm0000005   Ingmar Bergman     1918.0     2007.0
# ...             ...              ...        ...        ...
# 13419545  nm9992630   Karin Cherches        NaN        NaN
# 13419614  nm9992750     Loghan Bazan        NaN        NaN
# 13420288  nm9993535    Henry Lawfull     2006.0        NaN
# 13420358  nm9993616  Ryan Mac Lennan        NaN        NaN
# 13420426  nm9993693      Apsara Rani     1996.0        NaN
#
#                            primaryProfession  \
# 0               actor,miscellaneous,producer
# 1         actress,soundtrack,archive_footage
# 2          actress,music_department,producer
# 3              actor,writer,music_department
# 4                      writer,director,actor
# ...                                      ...
# 13419545                             actress
# 13419614                             actress
# 13420288                               actor
# 13420358                               actor
# 13420426                             actress
#
#                                      knownForTitles
# 0           tt0072308,tt0050419,tt0053137,tt0027125
# 1           tt0037382,tt0075213,tt0117057,tt0038355
# 2           tt0057345,tt0049189,tt0056404,tt0054452
# 3           tt0072562,tt0077975,tt0080455,tt0078723
# 4           tt0050986,tt0083922,tt0069467,tt0050976
# ...                                             ...
# 13419545                                  tt5039088
# 13419614                                  tt8736336
# 13420288                       tt10187208,tt5900600
# 13420358                                  tt4844148
# 13420426  tt12856788,tt8302382,tt13847502,tt8737752
#
# [160553 rows x 6 columns]

# %%
relations = pd.merge(relations, people[['nconst', 'primaryName']], on='nconst', how='inner')

# %%
relations.to_csv('relations.csv')

# %%
relations
# Out:
#            tconst      nconst profession       primaryName
# 0       tt0029284   nm0002050    actress       Irene Dunne
# 1       tt0029284   nm0000026      actor        Cary Grant
# 2       tt0029284   nm0000068      actor    Randolph Scott
# 3       tt0029284   nm0665850    actress      Gail Patrick
# 4       tt0029284   nm0794700    actress     Ann Shoemaker
# ...           ...         ...        ...               ...
# 415930  tt9911196   nm2063122    writers      Radek Bajgar
# 415931  tt9916270  nm10538402    writers  Lorenzo Collalti
# 415932  tt9916270   nm1480867    writers    Giacomo Cimini
# 415933  tt9916362   nm1893148    writers      Pablo Agüero
# 415934  tt9916362   nm3471432    writers    Katell Guillou
#
# [415935 rows x 4 columns]

# %%
relations['primaryName'] = relations['primaryName'].str.replace(' ', '_')

# %%
cast_crew = relations.drop('profession', axis=1).groupby('tconst').agg(lambda x: ' '.join(x))

# %%
movies = pd.merge(movies, cast_crew, on='tconst', how='inner')

# %%
people
# Out:
#              nconst      primaryName  birthYear  deathYear  \
# 0         nm0000001     Fred Astaire     1899.0     1987.0
# 1         nm0000002    Lauren Bacall     1924.0     2014.0
# 2         nm0000003  Brigitte Bardot     1934.0        NaN
# 3         nm0000004     John Belushi     1949.0     1982.0
# 4         nm0000005   Ingmar Bergman     1918.0     2007.0
# ...             ...              ...        ...        ...
# 13419545  nm9992630   Karin Cherches        NaN        NaN
# 13419614  nm9992750     Loghan Bazan        NaN        NaN
# 13420288  nm9993535    Henry Lawfull     2006.0        NaN
# 13420358  nm9993616  Ryan Mac Lennan        NaN        NaN
# 13420426  nm9993693      Apsara Rani     1996.0        NaN
#
#                            primaryProfession  \
# 0               actor,miscellaneous,producer
# 1         actress,soundtrack,archive_footage
# 2          actress,music_department,producer
# 3              actor,writer,music_department
# 4                      writer,director,actor
# ...                                      ...
# 13419545                             actress
# 13419614                             actress
# 13420288                               actor
# 13420358                               actor
# 13420426                             actress
#
#                                      knownForTitles
# 0           tt0072308,tt0050419,tt0053137,tt0027125
# 1           tt0037382,tt0075213,tt0117057,tt0038355
# 2           tt0057345,tt0049189,tt0056404,tt0054452
# 3           tt0072562,tt0077975,tt0080455,tt0078723
# 4           tt0050986,tt0083922,tt0069467,tt0050976
# ...                                             ...
# 13419545                                  tt5039088
# 13419614                                  tt8736336
# 13420288                       tt10187208,tt5900600
# 13420358                                  tt4844148
# 13420426  tt12856788,tt8302382,tt13847502,tt8737752
#
# [160553 rows x 6 columns]

# %%
def get_keywords(row):
    if isinstance(row, list):  # Check if it's already a list
        kws = [kw['name'] for kw in row]
        return ' '.join(kws)
    elif isinstance(row, dict):  # If it's a dictionary, directly access 'keywords' key
        kws = [kw['name'] for kw in row['keywords']]
        return ' '.join(kws)
    else:
        return ''

# %%
def get_countries(data, separator=' '):
    if data is None:
        return ''
    
    top_countries = ['US', 'GB', 'CN', 'FR', 'JP', 'DE', 'KR', 'CA', 'AU', 'IN']
    
    countries = []
    for country in data:
        name = format_name(country['name'])
        if name not in top_countries:
            countries.append(name)
        
    return separator.join(countries)

# %%
def format_name(name):
    if name is None:
        return None
    name = re.sub(r'[^\w\s]', '', name)
    parts = name.split()
    return '_'.join(parts)

# %%
movies['production_countries'] = movies['production_countries'].apply(get_countries)

# %%
movies['keywords'] = movies['keywords'].apply(get_keywords)

# %%
movies.drop(columns=['production_companies'], inplace=True)

# %%
movies.to_csv('movies.csv')

# %%
movies.to_pickle('data.pkl')

# %%
movies.reset_index(inplace=True)

# %%
def remove_quotes(text):
    if text is not None:
        return text.replace('"', '')
    else:
        return text

# %%
def remove_commas(text):
    if text is not None:
        return text.replace(',', ' ')
    else:
        return text

# %%
movies['overview'] = movies['overview'].apply(remove_quotes)

# %%
movies['genres'] = movies['genres'].apply(remove_commas)
movies['overview'] = movies['overview'].apply(remove_commas)

# %% [markdown]
# movies

# %%
movies.drop(columns='index', inplace=True)

# %%
movies = movies.replace({',': '', '"': ''}, regex=True)

# %%
def remove_punctuation(text):
    if isinstance(text, str):
        return re.sub(r'[^\w\s]', '', text)
    else:
        return text

# Apply the function to each cell in the DataFrame
movies = movies.applymap(remove_punctuation)

# %%
movies.to_csv('data.csv')

# %%
a = movies[['tconst','primaryTitle','startYear','runtimeMinutes','averageRating','numVotes']]

# %%
a.to_csv('bigdata.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

# %%
# Counting occurrences of each genre
genre_counts = (movies['genres'].apply(lambda x: x.split(',') if isinstance(x, str) else x).explode().value_counts()
).head(20)
# Plot the countplot of genres
plt.figure(figsize=(10, 6))
sns.barplot(x=genre_counts.values, y=genre_counts.index)
plt.xlabel('Number of Movies')
plt.ylabel('Genre')
plt.title('Movie Count by Genre')
plt.show()

# %%
genre_counts.to_csv('genres.csv')

# %%
# Plotting the box plot of the runtime durations.
plt.figure(figsize=(10, 3))  # Adjusting the figure size
sns.boxplot(data=movies, x='runtimeMinutes', color='pink')  # Changing y to x
plt.xlabel('Runtime (minutes)')  # Adjusting the label to x-axis
plt.title('Movie Runtime Durations')  # Keeping the title as it is
plt.show()
